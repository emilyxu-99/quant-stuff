# %%
# Calculating stock weights for Emilly & Ed's personal portfolio

import numpy as np
import pandas as pd
import IPython.display 

# !pip install pandas_datareader
import pandas_datareader
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
# Collecting data from the start of Black Thursday, the 2020 COVID-19 market crash.

# %matplotlib inline

assets = ['SBE', '^GSPC', 'VGT', 'XLK', 'IWL', 'IVV', 'GSLC', 'BLK', 'VOO', 'SPY', 'SPGM', 'MSFT', 'XLG', 'QQQE',
         'NVDA', 'NDAQ', 'BABA', 'SPYG', 'GOOGL', 'TAN', 'QCLN', 'PBW', 'TSLA', 'XPEV', 'LI', 'NIU', 'BYDDY',
         'ENPH', 'CSIQ', 'FSLR', 'PLUG', 'NOVA', 'SPWR', 'JD', 'ZM', 'ZG', 'PYPL', 'SQ','FVRR', 'PINS', 'SHOP', 
          'CRWD', 'NET', 'NOW', 'TTD', 'ETSY', 'CRSP', 'AMD', 'TSM', 'CRSR', 'APPN', 'ROKU', 'SPCE', 
          'MRNA', 'IWM', 'QQQ', 'FNGU','RSP', 'VWDRY', 'COST', 'DIA']

pf_data = pd.DataFrame()
for a in assets:
    pf_data[a] = wb.DataReader(a, data_source = 'yahoo', start = '2020-3-12')['Adj Close']

# %%
# Normalize data such that each stock price starts at $100

(pf_data / pf_data.iloc[0] * 100).plot(figsize = (20, 20))

# %%
pf_data.tail()
# Out:
#                   SBE        ^GSPC         VGT         XLK        IWL  \
# Date
# 2020-12-16  34.950001  3701.169922  346.839996  127.393303  88.889999
# 2020-12-17  35.500000  3722.479980  350.000000  128.400955  89.389999
# 2020-12-18  35.990002  3709.409912  349.059998  127.952003  89.080002
# 2020-12-21  39.000000  3694.919922  349.989990  128.080002  88.800003
# 2020-12-22  41.990002  3694.080078  354.070007  129.434998  88.927200
#
#                    IVV       GSLC         BLK         VOO         SPY  ...  \
# Date                                                                   ...
# 2020-12-16  369.899994  74.900002  698.369995  340.160004  368.598816  ...
# 2020-12-17  371.959991  75.459999  706.010010  342.010010  370.660004  ...
# 2020-12-18  370.489990  75.320000  698.799988  340.640015  369.179993  ...
# 2020-12-21  369.269989  75.099998  698.830017  339.589996  367.859985  ...
# 2020-12-22  369.234985  75.191299  694.780029  338.165009  367.899994  ...
#
#                   ROKU       SPCE        MRNA         IWM         QQQ  \
# Date
# 2020-12-16  325.820007  25.860001  137.029999  193.979996  308.420959
# 2020-12-17  329.480011  25.500000  144.000000  196.289993  310.437317
# 2020-12-18  340.709991  23.840000  140.229996  195.339996  309.498993
# 2020-12-21  354.000000  24.799999  138.300003  195.240005  308.920013
# 2020-12-22  349.511993  25.090000  123.095001  196.919998  309.670013
#
#                   FNGU         RSP      VWDRY        COST         DIA
# Date
# 2020-12-16  268.299988  126.179459  70.699997  369.440002  301.564606
# 2020-12-17  276.500000  126.896950  72.180000  370.290009  302.902008
# 2020-12-18  277.829987  126.598000  73.300003  367.000000  301.899994
# 2020-12-21  275.339996  125.589996  74.860001  364.970001  302.140015
# 2020-12-22  270.714996  125.345001  76.769997  361.804993  300.809998
#
# [5 rows x 61 columns]

# %%
pf_data.head()
# Out:
#               SBE        ^GSPC         VGT        XLK        IWL         IVV  \
# Date
# 2020-03-12  9.900  2480.639893  196.498047  74.414055  57.766876  244.199570
# 2020-03-13  9.750  2711.020020  218.140244  83.144249  63.131153  266.357605
# 2020-03-16  9.600  2386.129883  188.721161  71.658707  55.857384  235.528595
# 2020-03-17  9.600  2529.189941  200.093506  76.537346  59.322025  250.506622
# 2020-03-18  9.716  2398.100098  193.369415  73.653618  56.634964  236.558502
#
#                  GSLC         BLK         VOO         SPY  ...       ROKU  \
# Date                                                       ...
# 2020-03-12  50.074047  379.442535  224.352356  243.561539  ...  78.809998
# 2020-03-13  54.432625  406.518921  245.313583  264.382690  ...  80.949997
# 2020-03-16  48.221657  351.010376  216.516693  235.452972  ...  63.840000
# 2020-03-17  51.005199  379.973083  230.692245  248.165558  ...  69.459999
# 2020-03-18  48.538643  366.808197  218.081833  235.600204  ...  67.500000
#
#              SPCE       MRNA         IWM         QQQ       FNGU        RSP  \
# Date
# 2020-03-12  13.81  22.299999  110.396210  176.316177  38.779999  82.276268
# 2020-03-13  14.69  21.299999  117.790787  191.251144  43.959999  88.959007
# 2020-03-16  11.91  26.490000  102.163567  168.341568  32.009998  78.246979
# 2020-03-17  12.66  28.180000  106.846809  181.108871  30.000000  82.679199
# 2020-03-18  10.56  31.580000   98.564873  175.600250  26.500000  77.293709
#
#                 VWDRY        COST         DIA
# Date
# 2020-03-12  26.747967  270.980438  208.263916
# 2020-03-13  28.504196  292.689850  227.901260
# 2020-03-16  25.307463  274.204895  198.818329
# 2020-03-17  25.790920  297.260284  209.599274
# 2020-03-18  23.077644  297.754120  195.774536
#
# [5 rows x 61 columns]

# %%
returns = pf_data.pct_change()
returns.head()
# Out:
#                  SBE     ^GSPC       VGT       XLK       IWL       IVV  \
# Date
# 2020-03-12       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-03-13 -0.015151  0.092871  0.110140  0.117319  0.092861  0.090737
# 2020-03-16 -0.015385 -0.119841 -0.134863 -0.138140 -0.115217 -0.115743
# 2020-03-17  0.000000  0.059955  0.060260  0.068082  0.062027  0.063593
# 2020-03-18  0.012083 -0.051831 -0.033605 -0.037677 -0.045296 -0.055680
#
#                 GSLC       BLK       VOO       SPY  ...      ROKU      SPCE  \
# Date                                                ...
# 2020-03-12       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2020-03-13  0.087043  0.071358  0.093430  0.085486  ...  0.027154  0.063722
# 2020-03-16 -0.114104 -0.136546 -0.117388 -0.109424  ... -0.211365 -0.189244
# 2020-03-17  0.057724  0.082512  0.065471  0.053992  ...  0.088033  0.062972
# 2020-03-18 -0.048359 -0.034647 -0.054663 -0.050633  ... -0.028218 -0.165877
#
#                 MRNA       IWM       QQQ      FNGU       RSP     VWDRY  \
# Date
# 2020-03-12       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-03-13 -0.044843  0.066982  0.084706  0.133574  0.081223  0.065658
# 2020-03-16  0.243662 -0.132669 -0.119788 -0.271838 -0.120415 -0.112150
# 2020-03-17  0.063798  0.045841  0.075842 -0.062793  0.056644  0.019103
# 2020-03-18  0.120653 -0.077512 -0.030416 -0.116667 -0.065137 -0.105203
#
#                 COST       DIA
# Date
# 2020-03-12       NaN       NaN
# 2020-03-13  0.080114  0.094291
# 2020-03-16 -0.063155 -0.127612
# 2020-03-17  0.084081  0.054225
# 2020-03-18  0.001661 -0.065958
#
# [5 rows x 61 columns]

# %%
(returns.mean() * 250).head() # Assuming 250 trading days in a year
returns.mean()
# Out:
# SBE      0.008354
# ^GSPC    0.002231
# VGT      0.003268
# XLK      0.003101
# IWL      0.002390
#            ...
# FNGU     0.012129
# RSP      0.002399
# VWDRY    0.005749
# COST     0.001601
# DIA      0.002105
# Length: 61, dtype: float64

# %%
returns.corr().head()
# Out:
#             SBE     ^GSPC       VGT       XLK       IWL       IVV      GSLC  \
# SBE    1.000000  0.070755  0.042493  0.037129  0.067709  0.072147  0.067152
# ^GSPC  0.070755  1.000000  0.943116  0.946531  0.995447  0.999220  0.994441
# VGT    0.042493  0.943116  1.000000  0.997689  0.959972  0.940171  0.951446
# XLK    0.037129  0.946531  0.997689  1.000000  0.963394  0.943612  0.951935
# IWL    0.067709  0.995447  0.959972  0.963394  1.000000  0.994587  0.992636
#
#             BLK       VOO       SPY  ...      ROKU      SPCE      MRNA  \
# SBE    0.093651  0.070121  0.073632  ...  0.077157  0.156411  0.078372
# ^GSPC  0.815532  0.999036  0.998837  ...  0.351630  0.454949 -0.045230
# VGT    0.727820  0.939568  0.941004  ...  0.457212  0.451650 -0.014290
# XLK    0.727827  0.943128  0.943460  ...  0.444100  0.442257 -0.017201
# IWL    0.804992  0.994765  0.994294  ...  0.368714  0.452640 -0.033607
#
#             IWM       QQQ      FNGU       RSP     VWDRY      COST       DIA
# SBE    0.133900  0.023953 -0.002068  0.124919  0.099821 -0.018922  0.095308
# ^GSPC  0.895431  0.916633  0.722259  0.945281  0.547766  0.665896  0.977992
# VGT    0.779196  0.978766  0.823520  0.811623  0.498852  0.712313  0.879027
# XLK    0.772702  0.980623  0.815565  0.812145  0.493273  0.726744  0.883297
# IWL    0.868195  0.941357  0.752163  0.917985  0.542613  0.687622  0.961841
#
# [5 rows x 61 columns]

# %%
(returns.cov() * 250).head()
# Out:
#             SBE     ^GSPC       VGT       XLK       IWL       IVV      GSLC  \
# SBE    0.563299  0.017536  0.012151  0.010833  0.016434  0.017681  0.016108
# ^GSPC  0.017536  0.109040  0.118650  0.121508  0.106301  0.107737  0.104953
# VGT    0.012151  0.118650  0.145150  0.147768  0.118275  0.116958  0.115855
# XLK    0.010833  0.121508  0.147768  0.151131  0.121118  0.119779  0.118278
# IWL    0.016434  0.106301  0.118275  0.121118  0.104581  0.105022  0.102598
#
#             BLK       VOO       SPY  ...      ROKU      SPCE      MRNA  \
# SBE    0.033074  0.017310  0.017440  ...  0.043993  0.120703  0.055982
# ^GSPC  0.126717  0.108509  0.104088  ...  0.088209  0.154467 -0.014215
# VGT    0.130477  0.117741  0.113140  ...  0.132330  0.176926 -0.005182
# XLK    0.133139  0.120597  0.115748  ...  0.131156  0.176780 -0.006364
# IWL    0.122495  0.105812  0.101474  ...  0.090583  0.150509 -0.010344
#
#             IWM       QQQ      FNGU       RSP     VWDRY      COST       DIA
# SBE    0.039984  0.006169 -0.001635  0.034542  0.034048 -0.003780  0.025118
# ^GSPC  0.117642  0.103867  0.251193  0.115002  0.082203  0.058523  0.113398
# VGT    0.118112  0.127961  0.330450  0.113924  0.086373  0.072229  0.117595
# XLK    0.119516  0.130818  0.333931  0.116322  0.087149  0.075195  0.120576
# IWL    0.111707  0.104465  0.256189  0.109374  0.079747  0.059184  0.109221
#
# [5 rows x 61 columns]

# %%
num_assets = len(assets) 
num_assets

# num_assets will change; assuming here that some stock data on robinhood is not available on yahoo finance.
# Out:
# 61

# %%
weights = np.random.random(num_assets)
weights /= np.sum(weights)
weights

# Obtain num_assets weights that sum to 1
# Out:
# array([0.0128909 , 0.00044088, 0.03276492, 0.03814987, 0.02332598,
#        0.01122458, 0.01797311, 0.01832128, 0.02820335, 0.00261482,
#        0.02640955, 0.02558063, 0.0106769 , 0.02835184, 0.01325961,
#        0.03309335, 0.02945146, 0.00345393, 0.01668455, 0.00324932,
#        0.00719977, 0.00137289, 0.00250227, 0.01378403, 0.01282611,
#        0.01657198, 0.00078784, 0.00178457, 0.02298633, 0.00119322,
#        0.01089088, 0.03487913, 0.01941021, 0.01179611, 0.0057815 ,
#        0.03407387, 0.03016052, 0.00771889, 0.00806513, 0.00524914,
#        0.0107702 , 0.03836877, 0.03165829, 0.00645672, 0.01419261,
#        0.03760266, 0.0184701 , 0.02162367, 0.00886949, 0.02096232,
#        0.00101213, 0.01451723, 0.02503071, 0.01429884, 0.02678569,
#        0.03825548, 0.00829073, 0.00081765, 0.01579265, 0.01527631,
#        0.00579254])

# %%
# Expected portfolio return
np.sum(weights * returns.mean()) * 250
# Out:
# 1.508468949890245

# %%
# Variance
np.dot(weights.T, np.dot(returns.cov() * 250, weights))
# Out:
# 0.1373997010893223

# %%
# Volatility
np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 250, weights)))
# Out:
# 0.3706746566590739

# %%
pfolio_returns = []
pfolio_volatilities = []
p_weights = []

for x in range (5000):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    p_weights.append(weights)
    pfolio_returns.append(np.sum(weights * returns.mean()) * 250)
    pfolio_volatilities.append(np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 250, weights))))

pfolio_returns = np.array(pfolio_returns)
pfolio_volatilities = np.array(pfolio_volatilities)

# %%
portfolios = pd.DataFrame({'Return': pfolio_returns, 'Volatility': pfolio_volatilities})
portfolios.head()
# Out:
#      Return  Volatility
# 0  1.492345    0.360674
# 1  1.611230    0.371149
# 2  1.552998    0.373708
# 3  1.704845    0.389933
# 4  1.600204    0.375270

# %%
# Collect weights from monte carlo simulation and append to the corresponding ticker symbol

for counter, symbol in enumerate(pf_data.columns.tolist()):
    portfolios[symbol + ' weight'] = [w[counter] for w in p_weights]

# %%
portfolios.head()
# Out:
#      Return  Volatility  SBE weight  ^GSPC weight  VGT weight  XLK weight  \
# 0  1.492345    0.360674    0.013539      0.001501    0.032011    0.021934
# 1  1.611230    0.371149    0.020147      0.008497    0.026567    0.010946
# 2  1.552998    0.373708    0.020124      0.014833    0.019363    0.020043
# 3  1.704845    0.389933    0.029090      0.000753    0.023685    0.025913
# 4  1.600204    0.375270    0.027512      0.012071    0.026940    0.010618
#
#    IWL weight  IVV weight  GSLC weight  BLK weight  ...  ROKU weight  \
# 0    0.008459    0.022127     0.027442    0.002380  ...     0.007365
# 1    0.018819    0.004388     0.003045    0.019555  ...     0.026002
# 2    0.005508    0.019116     0.013082    0.022740  ...     0.013627
# 3    0.019236    0.001869     0.029012    0.018446  ...     0.006647
# 4    0.024336    0.028713     0.007157    0.005355  ...     0.023790
#
#    SPCE weight  MRNA weight  IWM weight  QQQ weight  FNGU weight  RSP weight  \
# 0     0.006937     0.021537    0.029627    0.013926     0.005608    0.026530
# 1     0.023251     0.016418    0.011085    0.030488     0.015045    0.002367
# 2     0.010311     0.028456    0.026196    0.029625     0.002157    0.024003
# 3     0.022710     0.028370    0.020056    0.010533     0.022988    0.023484
# 4     0.013587     0.010817    0.009290    0.024990     0.016117    0.010056
#
#    VWDRY weight  COST weight  DIA weight
# 0      0.016999     0.024612    0.021327
# 1      0.020609     0.009155    0.007766
# 2      0.027023     0.026872    0.029065
# 3      0.027492     0.014218    0.011970
# 4      0.005930     0.029108    0.030509
#
# [5 rows x 63 columns]

# %%
# Portfolio with the minimum variance

min_var_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
min_var_port.head()
# Out:
# Return          1.454207
# Volatility      0.342446
# SBE weight      0.024762
# ^GSPC weight    0.018093
# VGT weight      0.015451
# Name: 758, dtype: float64

# %%
# Risk free rate

rf = 0.0083

# %%
# Optimal risky portfolio -- highest Sharpe ratio
((portfolios['Return'] - rf) / (portfolios['Volatility'])).idxmax()
# Out:
# 4595

# %%
optimal_risky_port = portfolios.iloc[((portfolios['Return'] - rf) / (portfolios['Volatility'])).idxmax()]
optimal_risky_port.head()
# Out:
# Return          1.712171
# Volatility      0.358511
# SBE weight      0.022168
# ^GSPC weight    0.028429
# VGT weight      0.009028
# Name: 4595, dtype: float64

# %%
# Graph the 5000 potfolio returns
import matplotlib.pyplot as plt
plt.subplots(figsize = (20,10))
plt.scatter(portfolios['Volatility'], portfolios['Return'])
plt.scatter(min_var_port[1], min_var_port[0], color = 'y')
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color = 'r')

# %%
# Capital Allocation Line

cal_x = []
cal_y = []
utility = []
a = 5

for er in np.linspace(rf, max(pfolio_returns), 100):
    sd = (er - rf) / ((optimal_risky_port[0] - rf) / optimal_risky_port[1])
    u = er - 0.5*a*(sd**2)
    cal_x.append(sd)
    cal_y.append(er)
    utility.append(u)

data2 = {'utility': utility, 'cal_y': cal_y, 'cal_x': cal_x}
cal = pd.DataFrame(data2)
cal.head()
# Out:
#     utility     cal_y     cal_x
# 0  0.008300  0.008300  0.000000
# 1  0.026927  0.026966  0.003927
# 2  0.045477  0.045631  0.007855
# 3  0.063950  0.064297  0.011782
# 4  0.082345  0.082962  0.015710

# %%
plt.subplots(figsize = (20, 10))
plt.scatter(portfolios['Volatility'], portfolios['Return'])
plt.scatter(min_var_port[1], min_var_port[0], color = 'y')
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color = 'r')
plt.plot(cal_x, cal_y, color = 'g')

axes = plt.gca()
#axes.set_xlim([0, 2])
#axes.set_ylim([0.0, 5])

# %%
p_portfolios = portfolios.pivot_table(columns = ['Return', 'Volatility'])
p_portfolios.head()
# Out:
# Return        1.313415  1.372969  1.385355  1.390963  1.391459  1.398423  \
# Volatility    0.365926  0.359092  0.371049  0.360407  0.373478  0.368056
# AMD weight    0.026252  0.000446  0.021561  0.025535  0.026675  0.028470
# APPN weight   0.016959  0.003281  0.024103  0.021568  0.001899  0.012620
# BABA weight   0.035536  0.024297  0.000796  0.031479  0.018920  0.015862
# BLK weight    0.012395  0.017518  0.016362  0.011064  0.002863  0.016390
# BYDDY weight  0.010024  0.024083  0.021243  0.000812  0.024641  0.010401
#
# Return        1.403234  1.403740  1.406104  1.409060  ...  1.808414  1.808684  \
# Volatility    0.367010  0.367430  0.374239  0.364929  ...  0.387172  0.393797
# AMD weight    0.022259  0.030358  0.017264  0.006001  ...  0.008619  0.023986
# APPN weight   0.013113  0.002503  0.008565  0.011792  ...  0.017410  0.009987
# BABA weight   0.033151  0.009597  0.029741  0.032301  ...  0.008096  0.026021
# BLK weight    0.028631  0.030485  0.019801  0.022520  ...  0.004463  0.000796
# BYDDY weight  0.017383  0.000609  0.008308  0.027930  ...  0.030470  0.015610
#
# Return        1.814797  1.819028  1.827926  1.833214  1.836436  1.836570  \
# Volatility    0.399589  0.400572  0.385942  0.396928  0.405287  0.393073
# AMD weight    0.022356  0.004721  0.009391  0.023144  0.009390  0.019801
# APPN weight   0.020801  0.002298  0.021978  0.030611  0.016382  0.017815
# BABA weight   0.013718  0.011891  0.003912  0.008155  0.004875  0.002987
# BLK weight    0.004553  0.005203  0.018838  0.021718  0.013786  0.005514
# BYDDY weight  0.014147  0.028841  0.019433  0.017342  0.031165  0.025151
#
# Return        1.839565  1.856187
# Volatility    0.394812  0.393122
# AMD weight    0.016438  0.028153
# APPN weight   0.026359  0.027050
# BABA weight   0.005024  0.026410
# BLK weight    0.016627  0.027478
# BYDDY weight  0.012545  0.020570
#
# [5 rows x 5000 columns]

# %%
# Show me the best portfolio

optimal_risky_port
# Out:
# Return          1.712171
# Volatility      0.358511
# SBE weight      0.022168
# ^GSPC weight    0.028429
# VGT weight      0.009028
#                   ...
# FNGU weight     0.006395
# RSP weight      0.003642
# VWDRY weight    0.012982
# COST weight     0.017000
# DIA weight      0.030798
# Name: 4595, Length: 63, dtype: float64

# %%
#Select some high return and somewhat low volatility, show their weights
final_output = portfolios.loc[(portfolios['Return'] > 1.7121) & (portfolios['Volatility'] < 0.3586)] * 12033.99
final_output.transpose()
# Out:
#                       4595
# Return        20604.242874
# Volatility     4314.312763
# SBE weight      266.775163
# ^GSPC weight    342.115238
# VGT weight      108.639532
# ...                    ...
# FNGU weight      76.954796
# RSP weight       43.828428
# VWDRY weight    156.225584
# COST weight     204.574949
# DIA weight      370.624361
#
# [63 rows x 1 columns]

# %%
# Display final output: How much cash should I invest in each stock? What is the expected volatility and return?
with pd.option_context("display.max_rows", 63):
    display(final_output.transpose())
# Out:
#                       4595
# Return        20604.242874
# Volatility     4314.312763
# SBE weight      266.775163
# ^GSPC weight    342.115238
# VGT weight      108.639532
# XLK weight      133.202373
# IWL weight      110.709330
# IVV weight      150.882974
# GSLC weight     272.647557
# BLK weight      409.232329
# VOO weight      351.585286
# SPY weight      262.253631
# SPGM weight     227.664053
# MSFT weight     193.642584
# XLG weight      130.537891
# QQQE weight      16.516149
# NVDA weight     248.780013
# NDAQ weight     153.869539
# BABA weight     133.142953
# SPYG weight      42.764087
# GOOGL weight    106.302803
# TAN weight      253.445186
# QCLN weight     365.202857
# PBW weight      340.497852
# TSLA weight     119.706327
# XPEV weight     160.924460
# LI weight       416.816737
# NIU weight      358.751583
# BYDDY weight    305.424979
# ENPH weight      14.494272
# CSIQ weight     324.724767
# FSLR weight      50.788993
# PLUG weight     402.705311
# NOVA weight     113.449858
# SPWR weight     117.989468
# JD weight        72.064757
# ZM weight       244.101657
# ZG weight        77.688093
# PYPL weight     145.708559
# SQ weight         3.490935
# FVRR weight     328.044223
# PINS weight      29.297555
# SHOP weight     179.585858
# CRWD weight     285.279532
# NET weight      330.389305
# NOW weight      205.322952
# TTD weight      170.779223
# ETSY weight     245.570524
# CRSP weight      61.923053
# AMD weight       16.812578
# TSM weight      288.348998
# CRSR weight     383.130565
# APPN weight     393.044371
# ROKU weight       8.054188
# SPCE weight      24.278773
# MRNA weight     394.063162
# IWM weight       59.998089
# QQQ weight      228.618800
# FNGU weight      76.954796
# RSP weight       43.828428
# VWDRY weight    156.225584
# COST weight     204.574949
# DIA weight      370.624361
